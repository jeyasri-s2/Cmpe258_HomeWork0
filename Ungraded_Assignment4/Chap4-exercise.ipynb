# %%
import torch

# %% [markdown]
# Redefine the model to be w2 * t_u ** 2 + w1 * t_u + b.
#
# – What parts of the training loop and so on must be changed to accommodate
# this redefinition?
#
# • What parts are agnostic to swapping out the model?
#
# – Is the resulting loss higher or lower after training?
#
# • Is the result better or worse?

# %%
def model(t_u, w1,w2, b):
  return w2 * t_u**2 + w1 *t_u + b

# %%
def loss_fn(t_p, t_c):
  squared_diffs = (t_p - t_c)**2
  return squared_diffs.mean()

# %%
w1 = torch.ones(1)
w2 = torch.ones(1)
b = torch.zeros(1)

# %%
t_c = [0.5, 14.0, 15.0, 28.0, 11.0, 8.0, 3.0, -4.0, 6.0, 13.0, 21.0]
t_u = [35.7, 55.9, 58.2, 81.9, 56.3, 48.9, 33.9, 21.8, 48.4, 60.4, 68.4]
t_c = torch.tensor(t_c)
t_u = torch.tensor(t_u)

# %%
t_p = model(t_u, w1,w2, b)
t_p
# Out:
# tensor([1310.1901, 3180.7100, 3445.4399, 6789.5103, 3225.9900, 2440.1101,
#         1183.1101,  497.0399, 2390.9600, 3708.5601, 4746.9600])

# %%
loss = loss_fn(t_p, t_c)
loss
# Out:
# tensor(11709471.)

# %% [markdown]
# #conclusion

# %% [markdown]
# In the book, using equation wx+b, the loss value is tensor(1763.8846)
# but after changing the equation, the loss value increases.
#
# Result is not not good
